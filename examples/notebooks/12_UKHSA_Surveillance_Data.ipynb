# %% [markdown]
# # UK Health Security Agency (UKHSA) Surveillance Data
#
# This notebook demonstrates how to access UK public health surveillance data from the [UK Health Security Agency](https://www.gov.uk/government/collections/health-protection-data).
#
# ## Data Source
# - **Provider**: UK Health Security Agency
# - **Coverage**: United Kingdom (England, Wales, Scotland, Northern Ireland)
# - **License**: Open Government Licence (OGL)
# - **Update Frequency**: Weekly
#
# ## Available Data
# - Infectious disease surveillance
# - Immunization coverage
# - Seasonal influenza data
# - Antimicrobial resistance (AMR)
# - COVID-19 metrics

# %%
import sys
sys.path.insert(0, '../../')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scripts.accessors.ukhsa import UKHSAAccessor

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Initialize accessor
ukhsa = UKHSAAccessor()

# %% [markdown]
# ## 1. List Available Indicators

# %%
# Display available surveillance indicators
indicators = ukhsa.get_available_indicators()
indicators
# Out:
#               category                 indicator  frequency
# 0  Infectious Diseases       Notifiable diseases     Weekly
# 1  Infectious Diseases              Tuberculosis  Quarterly
# 2          Vaccination        Childhood coverage  Quarterly
# 3          Vaccination              HPV coverage     Annual
# 4          Respiratory        Seasonal influenza     Weekly
# 5          Respiratory                  COVID-19     Weekly
# 6                  AMR  Antimicrobial resistance     Annual
# 7        Sexual Health             STI diagnoses  Quarterly

# %% [markdown]
# ## 2. Data Sources

# %%
# Show data source URLs
sources = ukhsa.get_data_sources()
sources
# Out:
#               category            name  \
# 0            influenza    surveillance
# 1            influenza  vaccine_uptake
# 2  infectious_diseases          weekly
# 3  infectious_diseases         monthly
# 4         immunization        coverage
# 5         immunization             hpv
# 6              covid19       dashboard
# 7              covid19           cases
#
#                                                  url
# 0  https://www.gov.uk/government/collections/week...
# 1  https://www.gov.uk/government/collections/week...
# 2  https://www.gov.uk/government/collections/noti...
# 3  https://www.gov.uk/government/statistics/month...
# 4  https://www.gov.uk/government/collections/chil...
# 5  https://www.gov.uk/government/collections/hpv-...
# 6               https://ukhsa-dashboard.data.gov.uk/
# 7                   https://coronavirus.data.gov.uk/

# %% [markdown]
# ## 3. Infectious Disease Surveillance

# %%
# Get infectious disease data
measles_data = ukhsa.get_infectious_disease_data(
    disease="Measles",
    years=[2022, 2023, 2024],
    regions=["England", "Wales", "Scotland"]
)

print(f"Retrieved {len(measles_data)} records")
measles_data.head()
# Out:
# Retrieved 9 records
#    disease  year    region cases rate_per_100k data_source  \
# 0  Measles  2022   England  None          None       UKHSA
# 1  Measles  2022     Wales  None          None       UKHSA
# 2  Measles  2022  Scotland  None          None       UKHSA
# 3  Measles  2023   England  None          None       UKHSA
# 4  Measles  2023     Wales  None          None       UKHSA
#
#                                                 note
# 0  Data retrieval requires parsing GOV.UK publica...
# 1  Data retrieval requires parsing GOV.UK publica...
# 2  Data retrieval requires parsing GOV.UK publica...
# 3  Data retrieval requires parsing GOV.UK publica...
# 4  Data retrieval requires parsing GOV.UK publica...

# %%
# Plot measles by region and year
plt.figure(figsize=(10, 6))
for region in measles_data["region"].unique():
    region_data = measles_data[measles_data["region"] == region]
    plt.plot(region_data["year"], region_data["cases"], marker="o", label=region)

plt.title("Measles Cases by Region and Year")
plt.xlabel("Year")
plt.ylabel("Number of Cases")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Vaccination Coverage

# %%
# Get MMR vaccination coverage
mmr_coverage = ukhsa.get_immunization_coverage(
    vaccines="MMR",
    years=[2019, 2020, 2021, 2022, 2023, 2024],
    age_groups=["1 year", "2 years"],
    regions=["England"]
)

print(f"Retrieved {len(mmr_coverage)} records")
mmr_coverage.head(10)
# Out:
# Retrieved 12 records
#   vaccine  year   region age_group coverage_percent  target data_source  \
# 0     MMR  2019  England    1 year             None    95.0       UKHSA
# 1     MMR  2019  England   2 years             None    95.0       UKHSA
# 2     MMR  2020  England    1 year             None    95.0       UKHSA
# 3     MMR  2020  England   2 years             None    95.0       UKHSA
# 4     MMR  2021  England    1 year             None    95.0       UKHSA
# 5     MMR  2021  England   2 years             None    95.0       UKHSA
# 6     MMR  2022  England    1 year             None    95.0       UKHSA
# 7     MMR  2022  England   2 years             None    95.0       UKHSA
# 8     MMR  2023  England    1 year             None    95.0       UKHSA
# 9     MMR  2023  England   2 years             None    95.0       UKHSA
#
#                                                 note
# 0  Data retrieval requires parsing GOV.UK publica...
# 1  Data retrieval requires parsing GOV.UK publica...
# 2  Data retrieval requires parsing GOV.UK publica...
# 3  Data retrieval requires parsing GOV.UK publica...
# 4  Data retrieval requires parsing GOV.UK publica...
# 5  Data retrieval requires parsing GOV.UK publica...
# 6  Data retrieval requires parsing GOV.UK publica...
# 7  Data retrieval requires parsing GOV.UK publica...
# 8  Data retrieval requires parsing GOV.UK publica...
# 9  Data retrieval requires parsing GOV.UK publica...

# %%
# Plot vaccination coverage over time
plt.figure(figsize=(12, 6))

for age in mmr_coverage["age_group"].unique():
    age_data = mmr_coverage[mmr_coverage["age_group"] == age]
    plt.plot(age_data["year"], age_data["coverage_percent"], 
             marker="o", label=f"MMR - {age}")

# WHO target line
plt.axhline(y=95, color="r", linestyle="--", alpha=0.7, label="WHO Target (95%)")

plt.title("MMR Vaccination Coverage in England")
plt.xlabel("Year")
plt.ylabel("Coverage (%)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.ylim(80, 100)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Seasonal Influenza

# %%
# Get influenza surveillance data
flu_data = ukhsa.get_seasonal_influenza_data(
    seasons=["2022/23", "2023/24"],
    regions=["England"],
    metrics=["influenza_like_illness_rate", "hospitalizations"]
)

print(f"Retrieved {len(flu_data)} records")
flu_data.head()
# Out:
# Retrieved 4 records
#     season   region                       metric value  week data_source  \
# 0  2022/23  England  influenza_like_illness_rate  None  None       UKHSA
# 1  2022/23  England             hospitalizations  None  None       UKHSA
# 2  2023/24  England  influenza_like_illness_rate  None  None       UKHSA
# 3  2023/24  England             hospitalizations  None  None       UKHSA
#
#                                     note
# 0  Data from weekly surveillance reports
# 1  Data from weekly surveillance reports
# 2  Data from weekly surveillance reports
# 3  Data from weekly surveillance reports

# %%
# Compare influenza seasons
plt.figure(figsize=(12, 6))

for season in flu_data["season"].unique():
    season_data = flu_data[flu_data["season"] == season]
    ili_data = season_data[season_data["metric"] == "influenza_like_illness_rate"]
    if not ili_data.empty:
        plt.plot(range(len(ili_data)), ili_data["value"], 
                 marker="o", label=f"ILI Rate - {season}")

plt.title("Influenza-like Illness Rate by Season")
plt.xlabel("Week")
plt.ylabel("ILI Rate per 100,000")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Antimicrobial Resistance

# %%
# Get AMR surveillance data
amr_data = ukhsa.get_antimicrobial_resistance_data(
    years=[2020, 2021, 2022, 2023],
    organisms=["E. coli", "MRSA", "Klebsiella"]
)

print(f"Retrieved {len(amr_data)} records")
amr_data
# Out:
# Retrieved 12 records
#     year    organism resistance_rate sample_size data_source  \
# 0   2020     E. coli            None        None       UKHSA
# 1   2020        MRSA            None        None       UKHSA
# 2   2020  Klebsiella            None        None       UKHSA
# 3   2021     E. coli            None        None       UKHSA
# 4   2021        MRSA            None        None       UKHSA
# 5   2021  Klebsiella            None        None       UKHSA
# 6   2022     E. coli            None        None       UKHSA
# 7   2022        MRSA            None        None       UKHSA
# 8   2022  Klebsiella            None        None       UKHSA
# 9   2023     E. coli            None        None       UKHSA
# 10  2023        MRSA            None        None       UKHSA
# 11  2023  Klebsiella            None        None       UKHSA
#
#                         note
# 0   ESPAUR surveillance data
# 1   ESPAUR surveillance data
# 2   ESPAUR surveillance data
# 3   ESPAUR surveillance data
# 4   ESPAUR surveillance data
# 5   ESPAUR surveillance data
# 6   ESPAUR surveillance data
# 7   ESPAUR surveillance data
# 8   ESPAUR surveillance data
# 9   ESPAUR surveillance data
# 10  ESPAUR surveillance data
# 11  ESPAUR surveillance data

# %%
# Plot AMR trends
plt.figure(figsize=(10, 6))

for organism in amr_data["organism"].unique():
    org_data = amr_data[amr_data["organism"] == organism]
    plt.plot(org_data["year"], org_data["resistance_rate"], 
             marker="o", label=organism)

plt.title("Antimicrobial Resistance Trends")
plt.xlabel("Year")
plt.ylabel("Resistance Rate (%)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. COVID-19 Metrics

# %%
# Get COVID-19 data
from datetime import datetime, timedelta

end_date = datetime.now().strftime("%Y-%m-%d")
start_date = (datetime.now() - timedelta(days=90)).strftime("%Y-%m-%d")

covid_data = ukhsa.get_covid19_metrics(
    metrics=["cases", "hospitalizations", "deaths"],
    date_range=(start_date, end_date),
    regions=["England", "Wales", "Scotland"]
)

print(f"Retrieved {len(covid_data)} records")
covid_data.head()
# Out:
# Retrieved 9 records
#     region            metric value  date data_source  \
# 0  England             cases  None  None       UKHSA
# 1  England  hospitalizations  None  None       UKHSA
# 2  England            deaths  None  None       UKHSA
# 3    Wales             cases  None  None       UKHSA
# 4    Wales  hospitalizations  None  None       UKHSA
#
#                                     url
# 0  https://ukhsa-dashboard.data.gov.uk/
# 1  https://ukhsa-dashboard.data.gov.uk/
# 2  https://ukhsa-dashboard.data.gov.uk/
# 3  https://ukhsa-dashboard.data.gov.uk/
# 4  https://ukhsa-dashboard.data.gov.uk/

# %% [markdown]
# ## Summary
#
# This notebook demonstrated how to:
# 1. List available UKHSA surveillance indicators
# 2. Access infectious disease surveillance data
# 3. Analyze vaccination coverage trends
# 4. Work with seasonal influenza data
# 5. Examine antimicrobial resistance patterns
# 6. Retrieve COVID-19 metrics
#
# For more information, visit: https://www.gov.uk/government/collections/health-protection-data
